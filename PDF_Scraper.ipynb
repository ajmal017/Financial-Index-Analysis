# %%
pip install bs4
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=944357fff2bea0229ec125819160715c62135b47402108830331b62d1e1bbb19
#   Stored in directory: /Users/null/Library/Caches/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

AXJO = yf.Ticker("^AXJO")
DJI = yf.Ticker("^DJI")
SPY = yf.Ticker("SPY")
BBOZ = yf.Ticker("BBOZ.AX")
# get stock info
# print(BBOZ.info)

# get historical market data
AXJO_hist = AXJO.history(period="3y",interval="1d")
DJI_hist = DJI.history(period="20y",interval="1d")
SPY_hist = SPY.history(period="20y",interval="1d")
BBOZ_hist = BBOZ.history(period="3y",interval="1d")

print(BBOZ_hist)
# Out:
#              Open   High    Low  Close   Volume  Dividends  Stock Splits
# Date
# 2017-04-20  17.20  17.29  17.19  17.19    30423          0             0
# 2017-04-21  17.02  17.02  16.87  16.92    83975          0             0
# 2017-04-24  16.80  16.97  16.67  16.86    78646          0             0
# 2017-04-26  16.50  16.56  16.45  16.53    46393          0             0
# 2017-04-27  16.57  16.58  16.47  16.48    28267          0             0
# ...           ...    ...    ...    ...      ...        ...           ...
# 2020-04-14  12.10  12.15  11.39  11.42  3818136          0             0
# 2020-04-15  11.30  11.79  11.18  11.56  3590791          0             0
# 2020-04-16  12.21  12.28  11.74  11.74  4048550          0             0
# 2020-04-17  11.32  11.48  11.04  11.40  3712358          0             0
# 2020-04-20  11.64  12.05  11.40  12.05  2597666          0             0
#
# [759 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn

# Plot everything by leveraging the very powerful matplotlib package
#AXJO_hist['Close'].plot(figsize=(16, 9))
#DJI_hist['Close'].plot(figsize=(16, 9))
#SPY_hist['Close'].plot(figsize=(16, 9))

ax = AXJO_hist['Close'].plot(figsize=(16, 9),legend="1")
ax2 = ax.twinx()
BBOZ_hist['Close'].plot(figsize=(16, 9), ax=ax2, color="r",legend="2")
ax.figure.legend()
plt.show()

BBOZ_hist['Close'].corr(AXJO_hist['Close'])
# Out:
# -0.8821793647702331

# %%
import re
import requests
import time
from bs4 import BeautifulSoup
from requests.exceptions import RequestException

url = 'http://www.marketindex.com.au/rebalance-announcements'
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
response = requests.get(url,headers={'User-Agent': user_agent})
soup = BeautifulSoup(response.text,'html')

years = ['March','June','December','September']

downloads = list()

for each in soup.findAll('a'):
    for month in years:
        if month in str(each):
            link = each['href']
            download_url = 'http://www.marketindex.com.au/'+ link
            downloads += [download_url]

for each in downloads:
    r = requests.get(each,headers={'User-Agent': user_agent}, stream = True) 

    with open(each.split("/")[-1],"wb") as pdf: 
        for chunk in r.iter_content(chunk_size=2048): 

            # writing one chunk at a time to pdf file 
            if chunk: 
                pdf.write(chunk)
# Out:
#   File "<ipython-input-69-a6ccc37cd64f>", line 1
#     pip install requests
#               ^
# SyntaxError: invalid syntax

# %%
import camelot
tables = camelot.read_pdf('2011-rebalance-december.pdf')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-225-1cc7c28df5fa> in <module>
# ----> 1 import camelot
#       2 tables = camelot.read_pdf('2011-rebalance-december.pdf')
#       3
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/__init__.py in <module>
#       4
#       5 from .__version__ import __version__
# ----> 6 from .io import read_pdf
#       7 from .plotting import PlotMethods
#       8
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/io.py in <module>
#       3 import warnings
#       4
# ----> 5 from .handlers import PDFHandler
#       6 from .utils import validate_input, remove_extra
#       7
#
# ~/opt/anaconda3/lib/python3.7/site-packages/camelot/handlers.py in <module>
#       7
#       8 from .core import TableList
# ----> 9 from .parsers import Stream, Lattice
#      10 from .utils import (
#      11     TemporaryDirectory,
#
# ...

# %%
# Import libraries
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# Set the URL you want to webscrape from
url = 'http://www.marketindex.com.au/rebalance-announcements'
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
response = requests.get(url,headers={'User-Agent': user_agent})
soup = BeautifulSoup(response.text,'html')

# %%
years = ["March","June","December","September"]

downloads = list()

for each in soup.findAll('a'):
    for month in years:
        if month in str(each):
            link = each['href']
            download_url = 'http://www.marketindex.com.au/'+ link
            #myfile = requests.get(download_url,headers={'User-Agent': user_agent})
            print(download_url)
# Out:
# http://www.marketindex.com.au//sites/default/files/announcements/rebalance/2020-rebalance-march-delayed.pdf
# http://www.marketindex.com.au//sites/default/files/announcements/rebalance/2019-rebalance-december.pdf
# http://www.marketindex.com.au//sites/default/files/announcements/rebalance/2019-rebalance-september.pdf
# http://www.marketindex.com.au//sites/default/files/announcements/rebalance/2019-rebalance-june.pdf
# http://www.marketindex.com.au//sites/default/files/announcements/rebalance/2019-rebalance-march.pdf
# http://www.marketindex.com.au//sites/default/files/announcements/rebalance/2018-rebalance-december.pdf
# http://www.marketindex.com.au//sites/default/files/announcements/rebalance/2018-rebalance-september.pdf
# http://www.marketindex.com.au//sites/default/files/announcements/rebalance/2018-rebalance-june.pdf
# http://www.marketindex.com.au//sites/default/files/announcements/rebalance/2018-rebalance-march.pdf
# ...

# %%
any(ele in each for ele in test_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-9b66af92cb26> in <module>
# ----> 1 any(ele in each for ele in test_list)
#
# NameError: name 'test_list' is not defined

# %%
from urllib.request import urlopen, Request
headers = {‘User-Agent’: ‘Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3’}
reg_url = “https://www.marketindex.com.au/rebalance-announcements"
req = Request(url=reg_url, headers=headers) 
html = urlopen(req).read() 
print(html)
# Out:
#   File "<ipython-input-103-9a4036786c9c>", line 2
#     headers = {‘User-Agent’: ‘Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3’}
#                    ^
# SyntaxError: invalid character in identifier

# %%
# To download the whole data set, let's do a for loop through all a tags
line_count = 1 #variable to track what line you are on
for one_a_tag in soup.findAll('a'):  #'a' tags are for links
    if line_count >= 36: #code for text files starts at line 36
        link = one_a_tag['href']
        download_url = 'http://web.mta.info/developers/'+ link
        urllib.request.urlretrieve(download_url,'./'+link[link.find('/turnstile_')+1:]) 
        time.sleep(1) #pause the code for a sec
    #add 1 for next line
    line_count +=1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-145-7ca4511be0f6> in <module>
#      20         link = one_a_tag['href']
#      21         download_url = 'http://web.mta.info/developers/'+ link
# ---> 22         urllib.request.urlretrieve(download_url,'./'+link[link.find('/turnstile_')+1:])
#      23         time.sleep(1) #pause the code for a sec
#      24     #add 1 for next line
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     255         # Handle temporary file setup.
#     256         if filename:
# --> 257             tfp = open(filename, 'wb')
#     258         else:
#     259             tfp = tempfile.NamedTemporaryFile(delete=False)
#
# FileNotFoundError: [Errno 2] No such file or directory: './resources/nyct/turnstile/ts_Field_Description.txt'

# %%
import requests 
file_url = "http://www.marketindex.com.au//sites/default/files/announcements/rebalance/2020-rebalance-march-delayed.pdf"

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'

r = requests.get(file_url,headers={'User-Agent': user_agent}, stream = True) 

with open(file_url.split("/")[-1],"wb") as pdf: 
    for chunk in r.iter_content(chunk_size=2048): 
  
         # writing one chunk at a time to pdf file 
         if chunk: 
            pdf.write(chunk)

# %%
import re
import requests
import time
from bs4 import BeautifulSoup
from requests.exceptions import RequestException

url = 'http://www.marketindex.com.au/rebalance-announcements'
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
response = requests.get(url,headers={'User-Agent': user_agent})
soup = BeautifulSoup(response.text,'html')

years = ['March','June','December','September']

downloads = list()

for each in soup.findAll('a'):
    for month in years:
        if month in str(each):
            link = each['href']
            download_url = 'http://www.marketindex.com.au/'+ link
            downloads += [download_url]

for each in downloads:
    r = requests.get(each,headers={'User-Agent': user_agent}, stream = True) 

    with open(each.split("/")[-1],"wb") as pdf: 
        for chunk in r.iter_content(chunk_size=2048): 

            # writing one chunk at a time to pdf file 
            if chunk: 
                pdf.write(chunk)
