# %%
## Import packages
import os
from tabula import r ead_pdf
import pandas as pd

# %%
## Check the table structures in the PDFs
directory = os.getcwd()
for filename in os.listdir(directory):
    if filename.endswith(".pdf"):
        df = read_pdf(filename, pages = 'all')
        if df != []:
            print(filename)
            for each in df:
                print(len(each.columns))
                print(each)

## We can see inconsistency in the number of columns (2s, 4s, 3s and 1s).
# Out:
# 2012-rebalance-june.pdf
# 2
#   Unnamed: 0 S&P/ASX 50 Index – June 15, 2012 After Market Close
# 0     Action                                       Code Company
# 1   Addition                           DXS Dexus Property Group
# 2    Removal                                AWC Alumina Limited
# 2
#   Unnamed: 0 S&P/ASX 100 Index – June 15, 2012 After Market Close
# 0     Action                                       Code Company
# 1   Addition                       AUT Aurora Oil & Gas Limited
# 2   Addition                                      SPN SP AusNet
# 3    Removal                      AQP Aquarius Platinum Limited
# 4    Removal                                    CSR CSR Limited
# 2
#   Unnamed: 0 S&P/ASX 200 Index – June 15, 2012 After Market Close
# 0     Action                                       Code Company
# 1   Addition                                 CDD Cardno Limited
# 2   Addition            MTU M2 Telecommunications Group Limited
# ...

# %%
filename = '2012-rebalance-june.pdf'

df = read_pdf(filename, pages = 'all')

import pandas as pd

# %%
directory = os.getcwd()
for filename in os.listdir(directory):
    if filename.endswith(".pdf"):
        df = read_pdf(filename, pages = 'all')
        i = 1
        writer = pd.ExcelWriter(directory + '/Rebalances/Excel/' + filename + '.xlsx', engine = 'xlsxwriter')
        for each in df:
            each.to_excel(writer, sheet_name = str(i))
            i += 1
        writer.save()
        writer.close()
# Out:
# Got stderr: Apr 22, 2020 4:47:44 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font GHCLOA+Arial-BoldMT are not implemented in PDFBox and will be ignored
# Apr 22, 2020 4:47:45 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font GHCLOA+Arial-BoldMT are not implemented in PDFBox and will be ignored
# Apr 22, 2020 4:47:46 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font GHCLOA+Arial-BoldMT are not implemented in PDFBox and will be ignored
# Apr 22, 2020 4:47:46 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font GHCLOA+Arial-BoldMT are not implemented in PDFBox and will be ignored
# Apr 22, 2020 4:47:46 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font GHCLOA+Arial-BoldMT are not implemented in PDFBox and will be ignored
# ...

# %%
## Other Crap ##

## Extract the Index and Date

for each in df:
    i = 0
    for item in each.columns:
        if 'S&P' in item and ' – ' in item:
            instrument = item.split(' – ')[0]
            temp_date = item.split(' – ')[1]
            while temp_date[len(temp_date)-4:len(temp_date)-2] != '20':
                temp_date = temp_date[0:len(temp_date)-1]
            rebal_date = temp_date
            print(instrument)
            print(rebal_date)

            ## Check the table structures in the PDFs
directory = os.getcwd()
for filename in os.listdir(directory):
    if filename.endswith(".pdf"):
        df = read_pdf(filename, pages = 'all')
        if df != []:
            print(filename)
            for each in df:
                ## Check for the date and seperator in the DataFrame
                for item in each.columns:
                    if 'S&P' in item and ' – ' in item:
                        instrument = item.split(' – ')[0]
                        temp_date = item.split(' – ')[1]
                        while temp_date[len(temp_date)-4:len(temp_date)-2] != '20':
                            temp_date = temp_date[0:len(temp_date)-1]
                        rebal_date = temp_date
                ## Consolidate the columns
                if len(each.columns) > 2:
                    for item in each.columns:
                        if 'S&P' not in item and ' – ' not in item:
                            new_row = []
                            list1 = []
                            list2 = []
                            for i in range(0,len(each.columns)):
                                new_row += [each.columns[i]]
                                row = pd.Series(new_row,index=new_row)
                                entry = pd.DataFrame([row])
                            each = each.append(entry)
                            for item in new_row[1:len(new_row)]:
                                if list1 ==[]:
                                    list1 = each[item].tolist()
                                    id_list = [new_row[0]]
                                else:
                                    list2 = each[item].tolist()
                                    for i in range(0,len(list1)):
                                        list1[i] = list1[i] + " " + str(list2[i])
                                        id_list = id_list + [new_row[0]]
                            list_of_tuples = list(zip(id_list,list1))
                            each = pd.DataFrame(list_of_tuples)
            print(each)
# Out:
# S&P/ASX 50 Index
# Sep 16, 2011
# S&P/ASX 100 Index
# Sep 16, 2011
# S&P/ASX 200 Index
# Sep 16, 2011
# S&P/ASX 300 Index
# Sep 16, 2011
# S&P/ASX All Australian 50 Index
# Sep 16, 2011
# S&P/ASX All Australian 200 Index
# Sep 16, 2011
# 2012-rebalance-june.pdf
#   Unnamed: 0  \
# 0     Action
# 1   Addition
# 2   Addition
# 3   Addition
# 4   Addition
# 5    Removal
# 6    Removal
# 7    Removal
# 8    Removal
#
#   S&P/ASX All Australian 200 Index – June 15, 2012 After Market Close
# 0                                       Code Company
# 1                            BRU Buru Energy Limited
# 2                                 CDD Cardno Limited
# 3                     DLS Drillsearch Energy Limited
# 4            MTU M2 Telecommunications Group Limited
# 5        AAC Australian Agricultural Company Limited
# 6                            DTE Dart Energy Limited
# 7          ERA Energy Resources of Australia Limited
# 8                   WEC White Energy Company Limited
# ...

# %%
directory = os.getcwd()
for filename in os.listdir(directory):
    if filename.endswith(".pdf"):
        df = read_pdf(filename, pages = 'all')
        i = 1
        writer = pd.ExcelWriter(directory + '/' + filename + '.xlsx', engine = 'xlsxwriter')
        for each in df:
            each.to_excel(writer, sheet_name = str(i))
            i += 1
        writer.save()
        writer.close()
# Out:
# Got stderr: Apr 22, 2020 4:41:30 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font BLWLAE+ArialMT are not implemented in PDFBox and will be ignored
# Apr 22, 2020 4:41:30 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font MWDVQM+Arial-BoldMT are not implemented in PDFBox and will be ignored
# Apr 22, 2020 4:41:30 PM org.apache.pdfbox.pdmodel.font.PDFont <init>
# WARNING: Invalid ToUnicode CMap in font OYVQDY+SymbolMT
# Apr 22, 2020 4:41:30 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+120 (120) in font OYVQDY+SymbolMT
# Apr 22, 2020 4:41:30 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font BLWLAE+ArialMT are not implemented in PDFBox and will be ignored
# Apr 22, 2020 4:41:30 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# ...

# %%
U
rche0037
password R2ym0nd123
